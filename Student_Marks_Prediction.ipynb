# %%
import pandas as pd

data = {
    "hours": [1,2,3,4,5,6,7,8],
    "marks": [35,40,50,60,65,70,80,85]
}

df = pd.DataFrame(data)
df
# Out:
#    hours  marks
# 0      1     35
# 1      2     40
# 2      3     50
# 3      4     60
# 4      5     65
# 5      6     70
# 6      7     80
# 7      8     85

# %%
from sklearn.linear_model import LinearRegression
import pickle

X = df[['hours']]
y = df['marks']

model = LinearRegression()
model.fit(X, y)

print("Model trained successfully")
# Out:
# Model trained successfully

# %%
pickle.dump(model, open("model.pkl", "wb"))

# %%
# !pip install flask pyngrok

# %%
from flask import Flask, request, jsonify
import pickle

app = Flask(__name__)
model = pickle.load(open("model.pkl", "rb"))

@app.route("/")
def home():
    return "Student Marks Prediction API is running!"

@app.route("/predict", methods=["POST"])
def predict():
    hours = float(request.json["hours"])
    prediction = model.predict([[hours]])
    return jsonify({
        "predicted_marks": round(prediction[0], 2)
    })

app
# Out:
# <Flask '__main__'>

# %%
from pyngrok import ngrok

ngrok.kill()

public_url = ngrok.connect(5000)
print("Public URL:", public_url)

app.run(port=5000)
# Out:
# ERROR:pyngrok.process.ngrok:t=2026-02-01T10:57:59+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ERROR:pyngrok.process.ngrok:t=2026-02-01T10:57:59+0000 lvl=eror msg="session closing" obj=tunnels.session err="authentication failed: Usage of ngrok requires a verified account and authtoken.\n\nSign up for an account: https://dashboard.ngrok.com/signup\nInstall your authtoken: https://dashboard.ngrok.com/get-started/your-authtoken\r\n\r\nERR_NGROK_4018\r\n"
# ...

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3947jBhhWcPjN18qbH1YHV5s6tT_54veF4mCwWbjgSDGviyDa")

# %%
public_url = ngrok.connect(5000)
print("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://nonabstractly-vizorless-aleena.ngrok-free.dev" -> "http://localhost:5000"

# %%
import requests

url = "https://nonabstractly-vizorless-aleena.ngrok-free.dev/predict"  # include /predict

response = requests.post(url, json={"hours": 5})
print(response.json())
# Out:
# WARNING:pyngrok.process.ngrok:t=2026-02-01T11:12:05+0000 lvl=warn msg="failed to open private leg" id=799231c24fc4 privaddr=localhost:5000 err="dial tcp [::1]:5000: connect: connection refused"
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/requests/models.py in json(self, **kwargs)
#     975         try:
# --> 976             return complexjson.loads(self.text, **kwargs)
#     977         except JSONDecodeError as e:
#
# /usr/local/lib/python3.12/dist-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     513             and not use_decimal and not allow_nan and not kw):
# --> 514         return _default_decoder.decode(s)
#     515     if cls is None:
#
# ...

# %%
# Step 0: Install dependencies
# !pip install flask pyngrok

# Step 1: Imports
from flask import Flask, request, jsonify
import pickle
from pyngrok import ngrok
import threading

# Step 2: Load your trained model
model = pickle.load(open("model.pkl", "rb"))

# Step 3: Create Flask app
app = Flask(__name__)

@app.route("/")
def home():
    return "Student Marks Prediction API is running!"

@app.route("/predict", methods=["POST"])
def predict():
    hours = float(request.json["hours"])
    prediction = model.predict([[hours]])
    return jsonify({"predicted_marks": round(prediction[0], 2)})

# Step 4: Start ngrok
ngrok.kill()
public_url = ngrok.connect(5000)
print("Public URL:", public_url)

# Step 5: Run Flask in a separate thread
def run_app():
    app.run(port=5000)

thread = threading.Thread(target=run_app)
thread.start()
# Out:
# ...
# Public URL: NgrokTunnel: "https://nonabstractly-vizorless-aleena.ngrok-free.dev" -> "http://localhost:5000"

# %%
import requests

# Use ngrok URL
url = "https://nonabstractly-vizorless-aleena.ngrok-free.dev/predict"

# OR use localhost (if server is running locally)
# url = "http://localhost:5000/predict"


response = requests.post(url, json={"hours": 5})
print(response.json())
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# INFO:werkzeug:127.0.0.1 - - [01/Feb/2026 11:14:11] "POST /predict HTTP/1.1" 200 -
# {'predicted_marks': 64.29}
